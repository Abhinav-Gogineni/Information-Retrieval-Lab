# %%
# 2. Pre-processing of a Text Document: stop word removal and stemming

# Information Retrieval Lab
# Experiment: Pre-processing of a Text Document
# Stop Word Removal and Stemming

import re
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import nltk

# Download required NLTK data
nltk.download('stopwords')

# Input text document
text = """
Information retrieval is the process of obtaining relevant information
from a large collection of information resources. Search engines use
information retrieval techniques to find relevant documents.
"""

print("Original Text:")
print(text)

# Step 1: Convert text to lowercase
text = text.lower()

# Step 2: Remove punctuation and special characters
text = re.sub(r'[^a-zA-Z\s]', '', text)

# Step 3: Tokenization
words = text.split()

print("\nTokens:")
print(words)

# Step 4: Stop Word Removal
stop_words = set(stopwords.words('english'))

filtered_words = [word for word in words if word not in stop_words]

print("\nAfter Stop Word Removal:")
print(filtered_words)

# Step 5: Stemming
stemmer = PorterStemmer()

stemmed_words = [stemmer.stem(word) for word in filtered_words]

print("\nAfter Stemming:")
print(stemmed_words)

# Final pre-processed document
processed_text = ' '.join(stemmed_words)

print("\nFinal Pre-processed Text:")
print(processed_text)
# Out:
# Original Text:
#
# Information retrieval is the process of obtaining relevant information
# from a large collection of information resources. Search engines use
# information retrieval techniques to find relevant documents.
#
#
# Tokens:
# ['information', 'retrieval', 'is', 'the', 'process', 'of', 'obtaining', 'relevant', 'information', 'from', 'a', 'large', 'collection', 'of', 'information', 'resources', 'search', 'engines', 'use', 'information', 'retrieval', 'techniques', 'to', 'find', 'relevant', 'documents']
#
# After Stop Word Removal:
# ['information', 'retrieval', 'process', 'obtaining', 'relevant', 'information', 'large', 'collection', 'information', 'resources', 'search', 'engines', 'use', 'information', 'retrieval', 'techniques', 'find', 'relevant', 'documents']
#
# After Stemming:
# ['inform', 'retriev', 'process', 'obtain', 'relev', 'inform', 'larg', 'collect', 'inform', 'resourc', 'search', 'engin', 'use', 'inform', 'retriev', 'techniqu', 'find', 'relev', 'document']
#
# ...

# %%
# Information Retrieval Lab
# Experiment: Pre-processing of a Text Document
# Stop Word Removal and Stemming

import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

# Download stopwords
nltk.download('stopwords')

# Read the text document
with open("input.txt", "r", encoding="utf-8") as file:
    text = file.read()

print("Original Document:")
print(text)

# Convert text to lowercase
text = text.lower()

# Remove punctuation and special characters
text = re.sub(r'[^a-zA-Z\s]', '', text)

# Tokenization
words = text.split()

# Stop Word Removal
stop_words = set(stopwords.words('english'))
filtered_words = []

for word in words:
    if word not in stop_words:
        filtered_words.append(word)

print("\nAfter Stop Word Removal:")
print(filtered_words)

# Stemming
stemmer = PorterStemmer()

stemmed_words = []

for word in filtered_words:
    stemmed_words.append(stemmer.stem(word))

print("\nAfter Stemming:")
print(stemmed_words)

# Create final pre-processed text
processed_text = " ".join(stemmed_words)

print("\nFinal Pre-processed Document:")
print(processed_text)

# Save the processed text into another file
with open("processed.txt", "w", encoding="utf-8") as file:
    file.write(processed_text)

print("\nPre-processed document saved as 'processed.txt'")
# Out:
# Original Document:
# Information retrieval is the process of obtaining relevant information
# from a large collection of documents. The search engine retrieves
# relevant documents from the collection and provides useful information
# to the user.
#
# After Stop Word Removal:
# ['information', 'retrieval', 'process', 'obtaining', 'relevant', 'information', 'large', 'collection', 'documents', 'search', 'engine', 'retrieves', 'relevant', 'documents', 'collection', 'provides', 'useful', 'information', 'user']
#
# After Stemming:
# ['inform', 'retriev', 'process', 'obtain', 'relev', 'inform', 'larg', 'collect', 'document', 'search', 'engin', 'retriev', 'relev', 'document', 'collect', 'provid', 'use', 'inform', 'user']
#
# Final Pre-processed Document:
# inform retriev process obtain relev inform larg collect document search engin retriev relev document collect provid use inform user
#
# Pre-processed document saved as 'processed.txt'
# ...
